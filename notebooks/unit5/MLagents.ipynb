# %% [markdown]
# <a href="https://colab.research.google.com/github/Lizard2005/HuggingFace/blob/main/notebooks/unit5/MLagents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 5: An Introduction to ML-Agents

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/thumbnail.png" alt="Thumbnail"/>
#
# In this notebook, you'll learn about ML-Agents and train two agents.
#
# - The first one will learn to **shoot snowballs onto spawning targets**.
# - The second need to press a button to spawn a pyramid, then navigate to the pyramid, knock it over, **and move to the gold brick at the top**. To do that, it will need to explore its environment, and we will use a technique called curiosity.
#
# After that, you'll be able **to watch your agents playing directly on your browser**.
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ⬇️ Here is an example of what **you will achieve at the end of this unit.** ⬇️

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/pyramids.gif" alt="Pyramids"/>
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/snowballtarget.gif" alt="SnowballTarget"/>

# %% [markdown]
# ### 🎮 Environments:
#
# - [Pyramids](https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Learning-Environment-Examples.md#pyramids)
# - SnowballTarget
#
# ### 📚 RL-Library:
#
# - [ML-Agents](https://github.com/Unity-Technologies/ml-agents)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the GitHub Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Understand how works **ML-Agents**, the environment library.
# - Be able to **train agents in Unity Environments**.

# %% [markdown]
# ## This notebook is from the Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://huggingface.co/deep-rl-course/communication/publishing-schedule
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **Study [what is ML-Agents and how it works by reading Unit 5](https://huggingface.co/deep-rl-course/unit5/introduction)**  🤗

# %% [markdown]
# # Let's train our agents 🚀
#
# **To validate this hands-on for the certification process, you just need to push your trained models to the Hub**. There’s no results to attain to validate this one. But if you want to get nice results you can try to attain:
#
# - For `Pyramids` : Mean Reward = 1.75
# - For `SnowballTarget` : Mean Reward = 15 or 30 targets hit in an episode.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Clone the repository 🔽
#
# - We need to clone the repository, that contains **ML-Agents.**

# %%
# %%capture
# Clone the repository (can take 3min)
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %% [markdown]
# ## Setup the Virtual Environment 🔽
# - In order for the **ML-Agents** to run successfully in Colab,  Colab's Python version must meet the library's Python requirements.
#
# - We can check for the supported Python version under the `python_requires` parameter in the `setup.py` files. These files are required to set up the **ML-Agents** library for use and can be found in the following locations:
#   - `/content/ml-agents/ml-agents/setup.py`
#   - `/content/ml-agents/ml-agents-envs/setup.py`
#
# - Colab's Current Python version(can be checked using `!python --version`) doesn't match the library's `python_requires` parameter, as a result installation may silently fail and lead to errors like these, when executing the same commands later:
#   - `/bin/bash: line 1: mlagents-learn: command not found`
#   - `/bin/bash: line 1: mlagents-push-to-hf: command not found`
#
# - To resolve this, we'll create a virtual environment with a Python version compatible with the **ML-Agents** library.
#
# `Note:` *For future compatibility, always check the `python_requires` parameter in the installation files and set your virtual environment to the maximum supported Python version in the given below script if the Colab's Python version is not compatible*

# %%
# Colab's Current Python Version (Incompatible with ML-Agents)
# !python --version
# Out:
# Python 3.10.12

# %%
# Install virtualenv and create a virtual environment
# !pip install virtualenv
# !virtualenv myenv

# Download and install Miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# Activate Miniconda and install Python ver 3.10.12
# !source /usr/local/bin/activate
# !conda install -q -y --prefix /usr/local python=3.10.12 ujson  # Specify the version here

# Set environment variables for Python and conda paths
# !export PYTHONPATH=/usr/local/lib/python3.10/site-packages/
# !export CONDA_PREFIX=/usr/local/envs/myenv

# %%
# Python Version in New Virtual Environment (Compatible with ML-Agents)
# !python --version

# %% [markdown]
# ## Installing the dependencies 🔽

# %%
# %%capture
# Go inside the repository and install the package (can take 3min)
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %% [markdown]
# ## SnowballTarget ⛄
#
# If you need a refresher on how this environments work check this section 👉
# https://huggingface.co/deep-rl-course/unit5/snowball-target

# %% [markdown]
# ### Download and move the environment zip file in `./training-envs-executables/linux/`
# - Our environment executable is in a zip file.
# - We need to download it and place it to `./training-envs-executables/linux/`
# - We use a linux executable because we use colab, and colab machines OS is Ubuntu (linux)

# %%
# Here, we create training-envs-executables and linux
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %% [markdown]
# We downloaded the file SnowballTarget.zip from https://github.com/huggingface/Snowball-Target using `wget`

# %%
# !wget "https://github.com/huggingface/Snowball-Target/raw/main/SnowballTarget.zip" -O ./training-envs-executables/linux/SnowballTarget.zip
# Out:
# --2025-08-12 15:38:44--  https://github.com/huggingface/Snowball-Target/raw/main/SnowballTarget.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/huggingface/Snowball-Target/main/SnowballTarget.zip [following]
# --2025-08-12 15:38:47--  https://media.githubusercontent.com/media/huggingface/Snowball-Target/main/SnowballTarget.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35134213 (34M) [application/zip]
# Saving to: ‘./training-envs-executables/linux/SnowballTarget.zip’
#
# ./training-envs-exe 100%[===================>]  33.51M  3.83MB/s    in 10s
#
# 2025-08-12 15:39:00 (3.33 MB/s) - ‘./training-envs-executables/linux/SnowballTarget.zip’ saved [35134213/35134213]

# %% [markdown]
# We unzip the executable.zip file

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/SnowballTarget.zip

# %% [markdown]
# Make sure your file is accessible

# %%
# !chmod -R 755 ./training-envs-executables/linux/SnowballTarget

# %% [markdown]
# ### Define the SnowballTarget config file
# - In ML-Agents, you define the **training hyperparameters into config.yaml files.**
#
# There are multiple hyperparameters. To know them better, you should check for each explanation with [the documentation](https://github.com/Unity-Technologies/ml-agents/blob/release_20_docs/docs/Training-Configuration-File.md)
#
#
# So you need to create a `SnowballTarget.yaml` config file in ./content/ml-agents/config/ppo/
#
# We'll give you here a first version of this config (to copy and paste into your `SnowballTarget.yaml file`), **but you should modify it**.
#
# ```
# behaviors:
#   SnowballTarget:
#     trainer_type: ppo
#     summary_freq: 10000
#     keep_checkpoints: 10
#     checkpoint_interval: 50000
#     max_steps: 200000
#     time_horizon: 64
#     threaded: false
#     hyperparameters:
#       learning_rate: 0.0003
#       learning_rate_schedule: linear
#       batch_size: 128
#       buffer_size: 2048
#       beta: 0.005
#       epsilon: 0.2
#       lambd: 0.95
#       num_epoch: 3
#     network_settings:
#       normalize: false
#       hidden_units: 256
#       num_layers: 2
#       vis_encode_type: simple
#     reward_signals:
#       extrinsic:
#         gamma: 0.99
#         strength: 1.0
# ```

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/snowballfight_config1.png" alt="Config SnowballTarget"/>
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/snowballfight_config2.png" alt="Config SnowballTarget"/>

# %% [markdown]
# As an experimentation, you should also try to modify some other hyperparameters. Unity provides very [good documentation explaining each of them here](https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Training-Configuration-File.md).
#
# Now that you've created the config file and understand what most hyperparameters do, we're ready to train our agent 🔥.

# %% [markdown]
# ### Train the agent
#
# To train our agent, we just need to **launch mlagents-learn and select the executable containing the environment.**
#
# We define four parameters:
#
# 1. `mlagents-learn <config>`: the path where the hyperparameter config file is.
# 2. `--env`: where the environment executable is.
# 3. `--run_id`: the name you want to give to your training run id.
# 4. `--no-graphics`: to not launch the visualization during the training.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/mlagentslearn.png" alt="MlAgents learn"/>
#
# Train the model and use the `--resume` flag to continue training in case of interruption.
#
# > It will fail first time if and when you use `--resume`, try running the block again to bypass the error.

# %% [markdown]
# The training will take 10 to 35min depending on your config, go take a ☕️you deserve it 🤗.

# %%
# !mlagents-learn ./config/ppo/SnowballTarget.yaml --env=./training-envs-executables/linux/SnowballTarget/SnowballTarget --run-id="SnowballTarget1" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 2.1.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: SnowballTarget?team=0
# [INFO] Hyperparameters for behavior name SnowballTarget:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	128
# 	  buffer_size:	2048
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	50000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	256
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	10
# 	even_checkpoints:	False
# 	max_steps:	200000
# 	time_horizon:	64
# 	summary_freq:	10000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] SnowballTarget. Step: 10000. Time Elapsed: 32.376 s. Mean Reward: 4.136. Std of Reward: 2.370. Training.
# [INFO] SnowballTarget. Step: 20000. Time Elapsed: 59.384 s. Mean Reward: 7.109. Std of Reward: 2.858. Training.
# [INFO] SnowballTarget. Step: 30000. Time Elapsed: 85.936 s. Mean Reward: 9.205. Std of Reward: 2.668. Training.
# [INFO] SnowballTarget. Step: 40000. Time Elapsed: 111.965 s. Mean Reward: 11.364. Std of Reward: 2.772. Training.
# [INFO] SnowballTarget. Step: 50000. Time Elapsed: 140.212 s. Mean Reward: 13.545. Std of Reward: 2.115. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-49936.onnx
# [INFO] SnowballTarget. Step: 60000. Time Elapsed: 166.850 s. Mean Reward: 15.618. Std of Reward: 2.187. Training.
# [INFO] SnowballTarget. Step: 70000. Time Elapsed: 193.029 s. Mean Reward: 18.023. Std of Reward: 2.692. Training.
# [INFO] SnowballTarget. Step: 80000. Time Elapsed: 225.683 s. Mean Reward: 19.982. Std of Reward: 2.446. Training.
# [INFO] SnowballTarget. Step: 90000. Time Elapsed: 253.382 s. Mean Reward: 21.341. Std of Reward: 2.215. Training.
# [INFO] SnowballTarget. Step: 100000. Time Elapsed: 284.545 s. Mean Reward: 21.873. Std of Reward: 2.587. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-99960.onnx
# [INFO] SnowballTarget. Step: 110000. Time Elapsed: 314.036 s. Mean Reward: 23.667. Std of Reward: 2.419. Training.
# [INFO] SnowballTarget. Step: 120000. Time Elapsed: 342.950 s. Mean Reward: 24.222. Std of Reward: 2.128. Training.
# [INFO] SnowballTarget. Step: 130000. Time Elapsed: 373.917 s. Mean Reward: 24.309. Std of Reward: 2.689. Training.
# [INFO] SnowballTarget. Step: 140000. Time Elapsed: 401.775 s. Mean Reward: 25.068. Std of Reward: 2.027. Training.
# [INFO] SnowballTarget. Step: 150000. Time Elapsed: 433.087 s. Mean Reward: 25.418. Std of Reward: 1.904. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-149984.onnx
# [INFO] SnowballTarget. Step: 160000. Time Elapsed: 462.589 s. Mean Reward: 25.295. Std of Reward: 2.292. Training.
# [INFO] SnowballTarget. Step: 170000. Time Elapsed: 492.629 s. Mean Reward: 25.527. Std of Reward: 2.198. Training.
# [INFO] SnowballTarget. Step: 180000. Time Elapsed: 522.145 s. Mean Reward: 25.455. Std of Reward: 2.072. Training.
# [INFO] SnowballTarget. Step: 190000. Time Elapsed: 553.668 s. Mean Reward: 26.091. Std of Reward: 1.938. Training.
# [INFO] SnowballTarget. Step: 200000. Time Elapsed: 581.265 s. Mean Reward: 26.545. Std of Reward: 2.050. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-199984.onnx
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-200112.onnx
# [INFO] Copied results/SnowballTarget1/SnowballTarget/SnowballTarget-200112.onnx to results/SnowballTarget1/SnowballTarget.onnx.

# %%
# !python -m pip install mlagents==1.1.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlagents==1.1.0
#   Downloading mlagents-1.1.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.4/171.4 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Collecting mlagents-envs==1.1.0
#   Downloading mlagents_envs-1.1.0-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.6/89.6 kB 5.5 MB/s eta 0:00:00
# Collecting h5py>=2.9.0
#   Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 7.0 MB/s eta 0:00:0000:0100:01m
# Collecting grpcio<=1.48.2,>=1.11.0
#   Downloading grpcio-1.48.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 2.2 MB/s eta 0:00:0000:0100:01
# Collecting Pillow>=4.2.1
#   Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 9.1 MB/s eta 0:00:0000:0100:01m
# Collecting protobuf<3.21,>=3.6
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.9 MB/s eta 0:00:00a 0:00:01
# Collecting pyyaml>=3.1.0
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Collecting huggingface-hub>=0.14
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 9.9 MB/s eta 0:00:00a 0:00:01
# Collecting cattrs<1.7,>=1.1.0
#   Downloading cattrs-1.5.0-py3-none-any.whl (19 kB)
# Collecting attrs>=19.3.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 3.9 MB/s eta 0:00:00
# Collecting numpy<1.24.0,>=1.23.5
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 7.5 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard>=2.14
#   Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 9.0 MB/s eta 0:00:0000:0100:01m
# Collecting torch>=2.1.1
#   Downloading torch-2.8.0-cp310-cp310-manylinux_2_28_x86_64.whl (888.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.0/888.0 MB 837.5 kB/s eta 0:00:0000:0100:03
# Collecting onnx==1.15.0
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 716.0 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.16 in /home/dmin/.local/lib/python3.10/site-packages (from mlagents==1.1.0) (1.17.0)
# Collecting cloudpickle
#   Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Collecting filelock>=3.4.0
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting gym>=0.21.0
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 8.7 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pettingzoo==1.15.0
#   Downloading PettingZoo-1.15.0.tar.gz (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 9.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting requests
#   Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 4.3 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 7.6 MB/s eta 0:00:00
# Collecting tqdm>=4.42.1
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 4.6 MB/s eta 0:00:00
# Collecting hf-xet<2.0.0,>=1.1.3
#   Downloading hf_xet-1.1.7-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 11.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.9 in /home/dmin/.local/lib/python3.10/site-packages (from huggingface-hub>=0.14->mlagents==1.1.0) (25.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/dmin/.local/lib/python3.10/site-packages (from huggingface-hub>=0.14->mlagents==1.1.0) (4.14.1)
# Collecting absl-py>=0.4
#   Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/site-packages (from tensorboard>=2.14->mlagents==1.1.0) (65.5.0)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 8.5 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 7.9 MB/s eta 0:00:0000:0100:01m
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 5.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.8.90
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 8.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvjitlink-cu12==12.8.93
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 9.0 MB/s eta 0:00:00:00:0100:01
# Collecting nvidia-cudnn-cu12==9.10.2.21
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 969.3 kB/s eta 0:00:0000:0100:03
# Collecting nvidia-curand-cu12==10.3.9.90
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Collecting nvidia-cublas-cu12==12.8.4.1
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 2.6 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-nvtx-cu12==12.8.90
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 3.3 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 6.5 MB/s eta 0:00:00
# Collecting triton==3.4.0
#   Downloading triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 MB 1.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.3.3.83
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 5.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufile-cu12==1.13.1.3
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.1 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cusolver-cu12==11.7.3.90
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 4.5 MB/s eta 0:00:0000:0100:02
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 10.1 MB/s eta 0:00:0000:0100:01
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.8 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-nccl-cu12==2.27.3
#   Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 1.2 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-cuda-cupti-cu12==12.8.90
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 8.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 6.4 MB/s eta 0:00:0000:0100:01m
# Collecting nvidia-cusparselt-cu12==0.7.1
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.5.8.93
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting gym_notices>=0.0.4
#   Downloading gym_notices-0.1.0-py3-none-any.whl (3.3 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 9.6 MB/s eta 0:00:00a 0:00:01
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 6.7 MB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 kB 7.3 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 3.9 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 7.4 MB/s eta 0:00:00
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827728 sha256=146257e7c6b27ff63fc7eff1311926fe41f7e33a1a9644d22e29d1aecba4d720
#   Stored in directory: /home/dmin/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built gym
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, gym_notices, urllib3, triton, tqdm, tensorboard-data-server, sympy, pyyaml, protobuf, Pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, markdown, idna, hf-xet, grpcio, fsspec, filelock, cloudpickle, charset_normalizer, certifi, attrs, absl-py, werkzeug, requests, onnx, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, h5py, gym, cattrs, tensorboard, pettingzoo, nvidia-cusolver-cu12, huggingface-hub, torch, mlagents-envs, mlagents
#   DEPRECATION: pettingzoo is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pettingzoo ... done
# Successfully installed MarkupSafe-3.0.2 Pillow-11.3.0 absl-py-2.3.1 attrs-25.3.0 cattrs-1.5.0 certifi-2025.8.3 charset_normalizer-3.4.3 cloudpickle-3.1.1 filelock-3.18.0 fsspec-2025.7.0 grpcio-1.48.2 gym-0.26.2 gym_notices-0.1.0 h5py-3.14.0 hf-xet-1.1.7 huggingface-hub-0.34.4 idna-3.10 jinja2-3.1.6 markdown-3.8.2 mlagents-1.1.0 mlagents-envs-1.1.0 mpmath-1.3.0 networkx-3.4.2 numpy-1.23.5 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 onnx-1.15.0 pettingzoo-1.15.0 protobuf-3.20.3 pyyaml-6.0.2 requests-2.32.4 sympy-1.14.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 torch-2.8.0 tqdm-4.67.1 triton-3.4.0 urllib3-2.5.0 werkzeug-3.1.3
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip3.10 install --upgrade pip

# %% [markdown]
# ### Push the agent to the 🤗 Hub
#
# - Now that we trained our agent, we’re **ready to push it to the Hub to be able to visualize it playing on your browser🔥.**

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
# %pip install ipywidgets
import ipywidgets 
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /home/dmin/.local/lib/python3.10/site-packages (8.1.7)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/dmin/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: comm>=0.1.3 in /home/dmin/.local/lib/python3.10/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in /home/dmin/.local/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/dmin/.local/lib/python3.10/site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/dmin/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: stack_data in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.14.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: exceptiongroup in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.0)
# Requirement already satisfied: decorator in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: matplotlib-inline in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: jedi>=0.16 in /home/dmin/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/dmin/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/dmin/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/dmin/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/dmin/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/dmin/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/dmin/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip3.10 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# Then, we simply need to run `mlagents-push-to-hf`.
#
# And we define 4 parameters:
#
# 1. `--run-id`: the name of the training run id.
# 2. `--local-dir`: where the agent was saved, it’s results/<run_id name>, so in my case results/First Training.
# 3. `--repo-id`: the name of the Hugging Face repo you want to create or update. It’s always <your huggingface username>/<the repo name>
# If the repo does not exist **it will be created automatically**
# 4. `--commit-message`: since HF repos are git repository you need to define a commit message.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/mlagentspushtohub.png" alt="Push to Hub"/>
#
# For instance:
#
# `!mlagents-push-to-hf  --run-id="SnowballTarget1" --local-dir="./results/SnowballTarget1" --repo-id="ThomasSimonini/ppo-SnowballTarget"  --commit-message="First Push"`

# %%
# !mlagents-push-to-hf --run-id="SnowballTarget1" --local-dir="./results/SnowballTarget1" --repo-id="LizardAPN/ppo-SnowballTarget" --commit-message="Fist model for Snowball Target"
# Out:
# [INFO] This function will create a model card and upload your SnowballTarget1 into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SnowballTarget1 to the Hugging Face Hub
# Processing Files (0 / 0)                : |        |  0.00B /  0.00B
# New Data Upload                         : |        |  0.00B /  0.00B
#
#   ...allTarget/SnowballTarget-49936.onnx: 100%|████|  651kB /  651kB
#
#
#   ...SnowballTarget1/SnowballTarget.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-149984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-49936.onnx: 100%|████|  651kB /  651kB
#
#
#   ...SnowballTarget1/SnowballTarget.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-149984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (13 / 13)              : 100%|████| 27.0MB / 27.0MB,   ???B/s
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
#
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#
#
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#
#
#
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#
#
#
#
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#
#
#
#
#
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (13 / 13)              : 100%|████| 27.0MB / 27.0MB,  0.00B/s
# New Data Upload                         : |        |  0.00B /  0.00B,  0.00B/s
#   ...allTarget/SnowballTarget-99960.onnx: 100%|████|  651kB /  651kB
#   ...llTarget/SnowballTarget-200112.onnx: 100%|████|  651kB /  651kB
#   ...llTarget/SnowballTarget-199984.onnx: 100%|████|  651kB /  651kB
#   ....1754992645.DESKTOP-92SAKPB.46271.0: 100%|████| 18.8kB / 18.8kB
#   ...arget1/SnowballTarget/checkpoint.pt: 100%|████| 3.85MB / 3.85MB
#   ...wballTarget/SnowballTarget-49936.pt: 100%|████| 3.85MB / 3.85MB
#   ...ballTarget/SnowballTarget-200112.pt: 100%|████| 3.85MB / 3.85MB
#   ...ballTarget/SnowballTarget-149984.pt: 100%|████| 3.85MB / 3.85MB
#   ...ballTarget/SnowballTarget-199984.pt: 100%|████| 3.85MB / 3.85MB
#   ...wballTarget/SnowballTarget-99960.pt: 100%|████| 3.85MB / 3.85MB
# No files have been modified since last commit. Skipping to prevent empty commit.
# ^C
# Traceback (most recent call last):
#   File "/home/dmin/.local/bin/mlagents-push-to-hf", line 8, in <module>
#     sys.exit(main())
#   File "/home/dmin/.local/lib/python3.10/site-packages/mlagents/utils/push_to_hf.py", line 205, in main
#     package_to_hub(
#   File "/home/dmin/.local/lib/python3.10/site-packages/mlagents/utils/push_to_hf.py", line 170, in package_to_hub
#     api.upload_folder(
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py", line 1669, in _inner
#     return fn(self, *args, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py", line 4982, in upload_folder
#     commit_info = self.create_commit(
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py", line 1669, in _inner
#     return fn(self, *args, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py", line 4291, in create_commit
#     info = self.repo_info(repo_id=repo_id, repo_type=repo_type, revision=unquoted_revision, token=token)
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py", line 2853, in repo_info
#     return method(
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py", line 2637, in model_info
#     r = get_session().get(path, headers=headers, timeout=timeout, params=params)
#   File "/home/dmin/.local/lib/python3.10/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/huggingface_hub/utils/_http.py", line 96, in send
#     return super().send(request, *args, **kwargs)
#   File "/home/dmin/.local/lib/python3.10/site-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#   File "/home/dmin/.local/lib/python3.10/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#   File "/home/dmin/.local/lib/python3.10/site-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#   File "/home/dmin/.local/lib/python3.10/site-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#   File "/usr/local/lib/python3.10/http/client.py", line 1375, in getresponse
#     response.begin()
#   File "/usr/local/lib/python3.10/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#   File "/usr/local/lib/python3.10/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/local/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/local/lib/python3.10/ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/local/lib/python3.10/ssl.py", line 1130, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt

# %%
# !mlagents-push-to-hf  --run-id= # Add your run id  --local-dir= # Your local dir  --repo-id= # Your repo id  --commit-message= # Your commit message

# %% [markdown]
# Else, if everything worked you should have this at the end of the process(but with a different url 😆) :
#
#
#
# ```
# Your model is pushed to the hub. You can view your model here: https://huggingface.co/ThomasSimonini/ppo-SnowballTarget
# ```
#
# It’s the link to your model, it contains a model card that explains how to use it, your Tensorboard and your config file. **What’s awesome is that it’s a git repository, that means you can have different commits, update your repository with a new push etc.**

# %% [markdown]
# But now comes the best: **being able to visualize your agent online 👀.**

# %% [markdown]
# ### Watch your agent playing 👀
#
# For this step it’s simple:
#
# 1. Go here: https://huggingface.co/spaces/ThomasSimonini/ML-Agents-SnowballTarget
#
# 2. Launch the game and put it in full screen by clicking on the bottom right button
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/snowballtarget_load.png" alt="Snowballtarget load"/>

# %% [markdown]
# 1. In step 1, type your username (your username is case sensitive: for instance, my username is ThomasSimonini not thomassimonini or ThOmasImoNInI) and click on the search button.
#
# 2. In step 2, select your model repository.
#
# 3. In step 3, **choose which model you want to replay**:
#   - I have multiple ones, since we saved a model every 500000 timesteps.
#   - But since I want the more recent, I choose `SnowballTarget.onnx`
#
# 👉 What’s nice **is to try with different models step to see the improvement of the agent.**
#
# And don't hesitate to share the best score your agent gets on discord in #rl-i-made-this channel 🔥
#
# Let's now try a harder environment called Pyramids...

# %% [markdown]
# ## Pyramids 🏆
#
# ### Download and move the environment zip file in `./training-envs-executables/linux/`
# - Our environment executable is in a zip file.
# - We need to download it and place it to `./training-envs-executables/linux/`
# - We use a linux executable because we use colab, and colab machines OS is Ubuntu (linux)

# %% [markdown]
# We downloaded the file Pyramids.zip from from https://huggingface.co/spaces/unity/ML-Agents-Pyramids/resolve/main/Pyramids.zip using `wget`

# %%
# !wget "https://huggingface.co/spaces/unity/ML-Agents-Pyramids/resolve/main/Pyramids.zip" -O ./training-envs-executables/linux/Pyramids.zip
# Out:
# --2025-08-12 18:50:08--  https://huggingface.co/spaces/unity/ML-Agents-Pyramids/resolve/main/Pyramids.zip
# Resolving huggingface.co (huggingface.co)... 65.9.181.60, 65.9.181.75, 65.9.181.72, ...
# Connecting to huggingface.co (huggingface.co)|65.9.181.60|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.hf.co/repos/f2/c7/f2c7eed6c9ed94477803abde6483db87a56a1f82597e00780698db5998afdcda/1e0f1cfa88a380b42644d974525a7dbfe144089883a401526b8341c5441f7cae?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27Pyramids.zip%3B+filename%3D%22Pyramids.zip%22%3B&response-content-type=application%2Fzip&Expires=1755003009&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=tErHYgDL56TVgRQTh0YYy8rMx-wltXs9LmkIdWGyqCogqq4MZUMUzXVWfdEQxWy5k-C57iFhI0bVQ%7ERKxU9F0Ole1NgJQS4Dn5NN5bWjY1Kamg8hFWF8unDZ6%7EMBrWV7Il2FBhbgcKoAngiBDkWPL0XmTzzmFTIkV9IbBCEiMJXCYEnKMW8BMLSSuOCg8vVwKJ2GysVvGieK8vcB-eeuHI-K-TaIEsaen33CoGIyiOjTF0BcQYq-l3x0Avi96SXsGRI8ho3IEdrysmekFE2Jlxbis4EqEyu5tB2Qw9oVWNvcsv6h%7EJ%7E0QjWUCAuP-NXyXF4S%7E3pTlf8vEnFPV7eHCw__&Key-Pair-Id=K3RPWS32NSSJCE [following]
# --2025-08-12 18:50:09--  https://cdn-lfs.hf.co/repos/f2/c7/f2c7eed6c9ed94477803abde6483db87a56a1f82597e00780698db5998afdcda/1e0f1cfa88a380b42644d974525a7dbfe144089883a401526b8341c5441f7cae?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27Pyramids.zip%3B+filename%3D%22Pyramids.zip%22%3B&response-content-type=application%2Fzip&Expires=1755003009&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=tErHYgDL56TVgRQTh0YYy8rMx-wltXs9LmkIdWGyqCogqq4MZUMUzXVWfdEQxWy5k-C57iFhI0bVQ%7ERKxU9F0Ole1NgJQS4Dn5NN5bWjY1Kamg8hFWF8unDZ6%7EMBrWV7Il2FBhbgcKoAngiBDkWPL0XmTzzmFTIkV9IbBCEiMJXCYEnKMW8BMLSSuOCg8vVwKJ2GysVvGieK8vcB-eeuHI-K-TaIEsaen33CoGIyiOjTF0BcQYq-l3x0Avi96SXsGRI8ho3IEdrysmekFE2Jlxbis4EqEyu5tB2Qw9oVWNvcsv6h%7EJ%7E0QjWUCAuP-NXyXF4S%7E3pTlf8vEnFPV7eHCw__&Key-Pair-Id=K3RPWS32NSSJCE
# Resolving cdn-lfs.hf.co (cdn-lfs.hf.co)... 3.166.34.74, 3.166.34.27, 3.166.34.45, ...
# Connecting to cdn-lfs.hf.co (cdn-lfs.hf.co)|3.166.34.74|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42907187 (41M) [application/zip]
# Saving to: ‘./training-envs-executables/linux/Pyramids.zip’
#
# ./training-envs-exe 100%[===================>]  40.92M  7.39MB/s    in 5.5s
#
# 2025-08-12 18:50:15 (7.37 MB/s) - ‘./training-envs-executables/linux/Pyramids.zip’ saved [42907187/42907187]

# %% [markdown]
# We unzip the executable.zip file

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/Pyramids.zip

# %% [markdown]
# Make sure your file is accessible

# %%
# !chmod -R 755 ./training-envs-executables/linux/Pyramids/Pyramids

# %% [markdown]
# ###  Modify the PyramidsRND config file
# - Contrary to the first environment which was a custom one, **Pyramids was made by the Unity team**.
# - So the PyramidsRND config file already exists and is in ./content/ml-agents/config/ppo/PyramidsRND.yaml
# - You might asked why "RND" in PyramidsRND. RND stands for *random network distillation* it's a way to generate curiosity rewards. If you want to know more on that we wrote an article explaning this technique: https://medium.com/data-from-the-trenches/curiosity-driven-learning-through-random-network-distillation-488ffd8e5938
#
# For this training, we’ll modify one thing:
# - The total training steps hyperparameter is too high since we can hit the benchmark (mean reward = 1.75) in only 1M training steps.
# 👉 To do that, we go to config/ppo/PyramidsRND.yaml,**and modify these to max_steps to 1000000.**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit7/pyramids-config.png" alt="Pyramids config"/>

# %% [markdown]
# As an experimentation, you should also try to modify some other hyperparameters, Unity provides a very [good documentation explaining each of them here](https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Training-Configuration-File.md).
#
# We’re now ready to train our agent 🔥.

# %% [markdown]
# ### Train the agent
#
# The training will take 30 to 45min depending on your machine, go take a ☕️you deserve it 🤗.

# %%
# !mlagents-learn ./config/ppo/PyramidsRND.yaml --env=./training-envs-executables/linux/Pyramids/Pyramids --run-id="Pyramids Training 2" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Pyramids?team=0
# [INFO] Hyperparameters for behavior name Pyramids:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	128
# 	  buffer_size:	2048
# 	  learning_rate:	0.0003
# 	  beta:	0.01
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	500000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.01
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	64
# 	      num_layers:	3
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	5
# 	even_checkpoints:	False
# 	max_steps:	3000000
# 	time_horizon:	128
# 	summary_freq:	30000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Pyramids. Step: 30000. Time Elapsed: 63.504 s. Mean Reward: -1.000. Std of Reward: 0.000. Training.
# [INFO] Pyramids. Step: 60000. Time Elapsed: 126.427 s. Mean Reward: -1.000. Std of Reward: 0.000. Training.
# [INFO] Pyramids. Step: 90000. Time Elapsed: 189.597 s. Mean Reward: -0.870. Std of Reward: 0.504. Training.
# [INFO] Pyramids. Step: 120000. Time Elapsed: 251.398 s. Mean Reward: -0.929. Std of Reward: 0.393. Training.
# [INFO] Pyramids. Step: 150000. Time Elapsed: 312.180 s. Mean Reward: -0.866. Std of Reward: 0.519. Training.
# [INFO] Pyramids. Step: 180000. Time Elapsed: 374.620 s. Mean Reward: -0.936. Std of Reward: 0.355. Training.
# [INFO] Pyramids. Step: 210000. Time Elapsed: 437.694 s. Mean Reward: -0.583. Std of Reward: 0.870. Training.
# [INFO] Pyramids. Step: 240000. Time Elapsed: 500.509 s. Mean Reward: -0.622. Std of Reward: 0.902. Training.
# [INFO] Pyramids. Step: 270000. Time Elapsed: 563.527 s. Mean Reward: -0.655. Std of Reward: 0.835. Training.
# [INFO] Pyramids. Step: 300000. Time Elapsed: 624.912 s. Mean Reward: -0.636. Std of Reward: 0.845. Training.
# [INFO] Pyramids. Step: 330000. Time Elapsed: 687.639 s. Mean Reward: -0.071. Std of Reward: 1.176. Training.
# [INFO] Pyramids. Step: 360000. Time Elapsed: 749.730 s. Mean Reward: 0.011. Std of Reward: 1.147. Training.
# [INFO] Pyramids. Step: 390000. Time Elapsed: 811.854 s. Mean Reward: 0.600. Std of Reward: 1.166. Training.
# [INFO] Pyramids. Step: 420000. Time Elapsed: 874.406 s. Mean Reward: 0.577. Std of Reward: 1.206. Training.
# [INFO] Pyramids. Step: 450000. Time Elapsed: 937.213 s. Mean Reward: 0.850. Std of Reward: 1.142. Training.
# [INFO] Pyramids. Step: 480000. Time Elapsed: 1000.352 s. Mean Reward: 1.021. Std of Reward: 1.048. Training.
# [INFO] Exported results/Pyramids Training 2/Pyramids/Pyramids-499955.onnx
# [INFO] Pyramids. Step: 510000. Time Elapsed: 1064.886 s. Mean Reward: 1.302. Std of Reward: 0.898. Training.
# [INFO] Pyramids. Step: 540000. Time Elapsed: 1131.868 s. Mean Reward: 1.376. Std of Reward: 0.732. Training.
# [INFO] Pyramids. Step: 570000. Time Elapsed: 1197.164 s. Mean Reward: 1.308. Std of Reward: 0.897. Training.
# [INFO] Pyramids. Step: 600000. Time Elapsed: 1261.756 s. Mean Reward: 1.480. Std of Reward: 0.731. Training.
# [INFO] Pyramids. Step: 630000. Time Elapsed: 1327.007 s. Mean Reward: 1.102. Std of Reward: 1.049. Training.
# [INFO] Pyramids. Step: 660000. Time Elapsed: 1394.770 s. Mean Reward: 1.549. Std of Reward: 0.556. Training.
# [INFO] Pyramids. Step: 690000. Time Elapsed: 1461.153 s. Mean Reward: 1.573. Std of Reward: 0.521. Training.
# [INFO] Pyramids. Step: 720000. Time Elapsed: 1526.560 s. Mean Reward: 1.612. Std of Reward: 0.432. Training.
# [INFO] Pyramids. Step: 750000. Time Elapsed: 1592.260 s. Mean Reward: 1.641. Std of Reward: 0.337. Training.
# [INFO] Pyramids. Step: 780000. Time Elapsed: 1657.932 s. Mean Reward: 1.624. Std of Reward: 0.437. Training.
# [INFO] Pyramids. Step: 810000. Time Elapsed: 1725.360 s. Mean Reward: 1.529. Std of Reward: 0.600. Training.
# [INFO] Pyramids. Step: 840000. Time Elapsed: 1790.492 s. Mean Reward: 1.672. Std of Reward: 0.189. Training.
# [INFO] Pyramids. Step: 870000. Time Elapsed: 1855.689 s. Mean Reward: 1.580. Std of Reward: 0.455. Training.
# [INFO] Pyramids. Step: 900000. Time Elapsed: 1921.534 s. Mean Reward: 1.437. Std of Reward: 0.836. Training.
# [INFO] Pyramids. Step: 930000. Time Elapsed: 1988.404 s. Mean Reward: 1.609. Std of Reward: 0.564. Training.
# [INFO] Pyramids. Step: 960000. Time Elapsed: 2054.861 s. Mean Reward: 1.614. Std of Reward: 0.559. Training.
# [INFO] Pyramids. Step: 990000. Time Elapsed: 2123.354 s. Mean Reward: 1.687. Std of Reward: 0.313. Training.
# [INFO] Exported results/Pyramids Training 2/Pyramids/Pyramids-999934.onnx
# [INFO] Pyramids. Step: 1020000. Time Elapsed: 2190.915 s. Mean Reward: 1.701. Std of Reward: 0.299. Training.
# [INFO] Pyramids. Step: 1050000. Time Elapsed: 2257.508 s. Mean Reward: 1.726. Std of Reward: 0.170. Training.
# [INFO] Pyramids. Step: 1080000. Time Elapsed: 2323.377 s. Mean Reward: 1.553. Std of Reward: 0.596. Training.
# [INFO] Pyramids. Step: 1110000. Time Elapsed: 2388.796 s. Mean Reward: 1.642. Std of Reward: 0.491. Training.
# [INFO] Pyramids. Step: 1140000. Time Elapsed: 2455.245 s. Mean Reward: 1.607. Std of Reward: 0.572. Training.
# [INFO] Pyramids. Step: 1170000. Time Elapsed: 2523.871 s. Mean Reward: 1.622. Std of Reward: 0.558. Training.
# [INFO] Pyramids. Step: 1200000. Time Elapsed: 2591.244 s. Mean Reward: 1.669. Std of Reward: 0.406. Training.
# [INFO] Pyramids. Step: 1230000. Time Elapsed: 2658.780 s. Mean Reward: 1.677. Std of Reward: 0.413. Training.
# [INFO] Pyramids. Step: 1260000. Time Elapsed: 2726.864 s. Mean Reward: 1.693. Std of Reward: 0.307. Training.
# [INFO] Pyramids. Step: 1290000. Time Elapsed: 2795.187 s. Mean Reward: 1.702. Std of Reward: 0.391. Training.
# [INFO] Pyramids. Step: 1320000. Time Elapsed: 2861.940 s. Mean Reward: 1.595. Std of Reward: 0.614. Training.
# [INFO] Pyramids. Step: 1350000. Time Elapsed: 2932.029 s. Mean Reward: 1.696. Std of Reward: 0.391. Training.
# [INFO] Pyramids. Step: 1380000. Time Elapsed: 3000.121 s. Mean Reward: 1.672. Std of Reward: 0.484. Training.
# [INFO] Pyramids. Step: 1410000. Time Elapsed: 3068.565 s. Mean Reward: 1.568. Std of Reward: 0.664. Training.
# [INFO] Pyramids. Step: 1440000. Time Elapsed: 3136.055 s. Mean Reward: 1.660. Std of Reward: 0.486. Training.
# [INFO] Pyramids. Step: 1470000. Time Elapsed: 3203.297 s. Mean Reward: 1.686. Std of Reward: 0.314. Training.
# [INFO] Pyramids. Step: 1500000. Time Elapsed: 3270.357 s. Mean Reward: 1.622. Std of Reward: 0.504. Training.
# [INFO] Exported results/Pyramids Training 2/Pyramids/Pyramids-1499998.onnx
# [INFO] Pyramids. Step: 1530000. Time Elapsed: 3337.518 s. Mean Reward: 1.721. Std of Reward: 0.299. Training.
# [INFO] Pyramids. Step: 1560000. Time Elapsed: 3408.336 s. Mean Reward: 1.716. Std of Reward: 0.379. Training.
# [INFO] Pyramids. Step: 1590000. Time Elapsed: 3476.020 s. Mean Reward: 1.672. Std of Reward: 0.531. Training.
# [INFO] Pyramids. Step: 1620000. Time Elapsed: 3542.694 s. Mean Reward: 1.704. Std of Reward: 0.392. Training.
# [INFO] Pyramids. Step: 1650000. Time Elapsed: 3609.256 s. Mean Reward: 1.656. Std of Reward: 0.538. Training.
# [INFO] Pyramids. Step: 1680000. Time Elapsed: 3676.514 s. Mean Reward: 1.727. Std of Reward: 0.295. Training.
# [INFO] Pyramids. Step: 1710000. Time Elapsed: 3744.291 s. Mean Reward: 1.681. Std of Reward: 0.471. Training.
# [INFO] Pyramids. Step: 1740000. Time Elapsed: 3813.258 s. Mean Reward: 1.688. Std of Reward: 0.455. Training.
# [INFO] Pyramids. Step: 1770000. Time Elapsed: 3881.938 s. Mean Reward: 1.741. Std of Reward: 0.292. Training.
# [INFO] Pyramids. Step: 1800000. Time Elapsed: 3949.712 s. Mean Reward: 1.724. Std of Reward: 0.292. Training.
# [INFO] Pyramids. Step: 1830000. Time Elapsed: 4017.547 s. Mean Reward: 1.755. Std of Reward: 0.146. Training.
# [INFO] Pyramids. Step: 1860000. Time Elapsed: 4089.223 s. Mean Reward: 1.731. Std of Reward: 0.368. Training.
# [INFO] Pyramids. Step: 1890000. Time Elapsed: 4156.826 s. Mean Reward: 1.717. Std of Reward: 0.386. Training.
# [INFO] Pyramids. Step: 1920000. Time Elapsed: 4224.243 s. Mean Reward: 1.656. Std of Reward: 0.484. Training.
# [INFO] Pyramids. Step: 1950000. Time Elapsed: 4291.985 s. Mean Reward: 1.717. Std of Reward: 0.302. Training.
# [INFO] Pyramids. Step: 1980000. Time Elapsed: 4362.121 s. Mean Reward: 1.751. Std of Reward: 0.274. Training.
# [INFO] Exported results/Pyramids Training 2/Pyramids/Pyramids-1999932.onnx
# [INFO] Pyramids. Step: 2010000. Time Elapsed: 4431.304 s. Mean Reward: 1.786. Std of Reward: 0.107. Training.
# [INFO] Pyramids. Step: 2040000. Time Elapsed: 4500.917 s. Mean Reward: 1.755. Std of Reward: 0.158. Training.
# [INFO] Pyramids. Step: 2070000. Time Elapsed: 4569.373 s. Mean Reward: 1.688. Std of Reward: 0.313. Training.
# [INFO] Pyramids. Step: 2100000. Time Elapsed: 4638.248 s. Mean Reward: 1.756. Std of Reward: 0.143. Training.
# [INFO] Pyramids. Step: 2130000. Time Elapsed: 4706.982 s. Mean Reward: 1.763. Std of Reward: 0.262. Training.
# [INFO] Pyramids. Step: 2160000. Time Elapsed: 4773.787 s. Mean Reward: 1.732. Std of Reward: 0.292. Training.
# [INFO] Pyramids. Step: 2190000. Time Elapsed: 4842.039 s. Mean Reward: 1.750. Std of Reward: 0.278. Training.
# [INFO] Pyramids. Step: 2220000. Time Elapsed: 4909.495 s. Mean Reward: 1.706. Std of Reward: 0.385. Training.
# [INFO] Pyramids. Step: 2250000. Time Elapsed: 4978.889 s. Mean Reward: 1.746. Std of Reward: 0.273. Training.
# [INFO] Pyramids. Step: 2280000. Time Elapsed: 5046.835 s. Mean Reward: 1.717. Std of Reward: 0.372. Training.
# [INFO] Pyramids. Step: 2310000. Time Elapsed: 5114.298 s. Mean Reward: 1.756. Std of Reward: 0.275. Training.
# [INFO] Pyramids. Step: 2340000. Time Elapsed: 5182.613 s. Mean Reward: 1.767. Std of Reward: 0.151. Training.
# [INFO] Pyramids. Step: 2370000. Time Elapsed: 5250.287 s. Mean Reward: 1.711. Std of Reward: 0.443. Training.
# [INFO] Pyramids. Step: 2400000. Time Elapsed: 5318.245 s. Mean Reward: 1.699. Std of Reward: 0.397. Training.
# [INFO] Pyramids. Step: 2430000. Time Elapsed: 5385.539 s. Mean Reward: 1.690. Std of Reward: 0.454. Training.
# [INFO] Pyramids. Step: 2460000. Time Elapsed: 5452.380 s. Mean Reward: 1.698. Std of Reward: 0.448. Training.
# [INFO] Pyramids. Step: 2490000. Time Elapsed: 5521.625 s. Mean Reward: 1.787. Std of Reward: 0.113. Training.
# [INFO] Exported results/Pyramids Training 2/Pyramids/Pyramids-2499916.onnx
# [INFO] Pyramids. Step: 2520000. Time Elapsed: 5590.298 s. Mean Reward: 1.731. Std of Reward: 0.298. Training.
# [INFO] Pyramids. Step: 2550000. Time Elapsed: 5658.352 s. Mean Reward: 1.735. Std of Reward: 0.373. Training.
# [INFO] Pyramids. Step: 2580000. Time Elapsed: 5727.352 s. Mean Reward: 1.761. Std of Reward: 0.269. Training.
# [INFO] Pyramids. Step: 2610000. Time Elapsed: 5796.598 s. Mean Reward: 1.786. Std of Reward: 0.128. Training.
# [INFO] Pyramids. Step: 2640000. Time Elapsed: 5866.495 s. Mean Reward: 1.731. Std of Reward: 0.382. Training.
# [INFO] Pyramids. Step: 2670000. Time Elapsed: 5934.476 s. Mean Reward: 1.729. Std of Reward: 0.371. Training.
# [INFO] Pyramids. Step: 2700000. Time Elapsed: 6002.693 s. Mean Reward: 1.778. Std of Reward: 0.134. Training.
# [INFO] Pyramids. Step: 2730000. Time Elapsed: 6071.588 s. Mean Reward: 1.749. Std of Reward: 0.279. Training.
# [INFO] Pyramids. Step: 2760000. Time Elapsed: 6138.233 s. Mean Reward: 1.744. Std of Reward: 0.362. Training.
# [INFO] Pyramids. Step: 2790000. Time Elapsed: 6207.949 s. Mean Reward: 1.747. Std of Reward: 0.269. Training.
# [INFO] Pyramids. Step: 2820000. Time Elapsed: 6276.380 s. Mean Reward: 1.788. Std of Reward: 0.114. Training.
# [INFO] Pyramids. Step: 2850000. Time Elapsed: 6343.300 s. Mean Reward: 1.716. Std of Reward: 0.379. Training.
# [INFO] Pyramids. Step: 2880000. Time Elapsed: 6413.081 s. Mean Reward: 1.773. Std of Reward: 0.256. Training.
# [INFO] Pyramids. Step: 2910000. Time Elapsed: 6480.305 s. Mean Reward: 1.698. Std of Reward: 0.398. Training.
# [INFO] Pyramids. Step: 2940000. Time Elapsed: 6549.398 s. Mean Reward: 1.758. Std of Reward: 0.135. Training.
# [INFO] Pyramids. Step: 2970000. Time Elapsed: 6616.065 s. Mean Reward: 1.747. Std of Reward: 0.284. Training.
# [INFO] Pyramids. Step: 3000000. Time Elapsed: 6685.465 s. Mean Reward: 1.761. Std of Reward: 0.271. Training.
# [INFO] Exported results/Pyramids Training 2/Pyramids/Pyramids-2999974.onnx
# [INFO] Exported results/Pyramids Training 2/Pyramids/Pyramids-3000102.onnx
# [INFO] Copied results/Pyramids Training 2/Pyramids/Pyramids-3000102.onnx to results/Pyramids Training 2/Pyramids.onnx.

# %% [markdown]
# ### Push the agent to the 🤗 Hub
#
# - Now that we trained our agent, we’re **ready to push it to the Hub to be able to visualize it playing on your browser🔥.**

# %%
# !mlagents-push-to-hf  --run-id='Pyramids_Training_2' --local-dir='./results/Pyramids_Training_2' --repo-id='LizardAPN/ppo-Pyramids' --commit-message='First model for Pyramids' # Your local dir  --repo-id= # Your repo id  --commit-message= # Your commit message
# Out:
# [INFO] This function will create a model card and upload your Pyramids_Training_2 into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo Pyramids_Training_2 to the Hugging Face Hub
# Processing Files (0 / 0)                : |        |  0.00B /  0.00B
# New Data Upload                         : |        |  0.00B /  0.00B
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-3000102.pt:   1%|    | 79.4kB / 8.66MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :   1%|    |  563kB / 61.4MB,  352kB/s
# New Data Upload                         :   1%|    |  563kB / 61.4MB,  352kB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           :   1%|    |  180kB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           :   1%|    |  180kB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   1%|    | 79.4kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   1%|    | 13.0kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           :   1%|    |  180kB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   2%|    |  159kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   2%|    |  159kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   2%|    |  159kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   2%|    |  159kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :   2%|    | 1.13MB / 61.4MB,  469kB/s
# New Data Upload                         :   2%|    | 1.13MB / 61.4MB,  469kB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   2%|    |  159kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   2%|    |  159kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   2%|    |  159kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   2%|    |  159kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   2%|    | 26.1kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           :   2%|    |  360kB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   5%|▏   | 65.1kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   5%|▏   |  397kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   5%|▏   | 65.1kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   5%|▏   |  397kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   5%|▏   | 65.1kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   5%|▏   |  397kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   5%|▏   | 65.1kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   5%|▏   |  397kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   5%|▏   | 65.1kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :   5%|▏   | 2.81MB / 61.4MB, 1.01MB/s
# New Data Upload                         :   5%|▏   | 2.81MB / 61.4MB, 1.01MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   6%|▎   |  556kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   6%|▎   |  556kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   6%|▎   |  556kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   6%|▎   |  556kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :   6%|▎   | 3.94MB / 61.4MB, 1.31MB/s
# New Data Upload                         :   6%|▎   | 3.94MB / 61.4MB, 1.31MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   6%|▎   |  556kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   6%|▎   |  556kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   6%|▎   |  556kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   6%|▎   |  556kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   6%|▎   | 91.2kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           :   6%|▎   | 1.26MB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:   9%|▎   |  130kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:   9%|▎   |  794kB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:   9%|▎   |  130kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:   9%|▎   |  794kB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:   9%|▎   |  130kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:   9%|▎   |  794kB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:   9%|▎   |  130kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:   9%|▎   |  794kB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:   9%|▎   |  130kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :   9%|▎   | 5.63MB / 61.4MB, 1.66MB/s
# New Data Upload                         :   9%|▎   | 5.63MB / 61.4MB, 1.66MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  12%|▍   |  169kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  12%|▍   | 1.03MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  12%|▍   |  169kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  12%|▍   | 1.03MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  12%|▍   |  169kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  12%|▍   | 1.03MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  12%|▍   |  169kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  12%|▍   | 1.03MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  12%|▍   |  169kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  12%|▍   | 7.32MB / 61.4MB, 2.03MB/s
# New Data Upload                         :  12%|▍   | 7.32MB / 61.4MB, 2.03MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  17%|▋   | 1.51MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  17%|▋   | 1.51MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  17%|▋   | 1.51MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  17%|▋   | 1.51MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  17%|▋   | 10.7MB / 61.4MB, 2.81MB/s
# New Data Upload                         :  17%|▋   | 10.7MB / 61.4MB, 2.81MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  17%|▋   | 1.51MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  17%|▋   | 1.51MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  17%|▋   | 1.51MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  17%|▋   | 1.51MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  17%|▋   |  248kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           :  17%|▋   | 3.42MB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  25%|▉   |  352kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  25%|▉   | 2.14MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  25%|▉   |  352kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  25%|▉   | 2.14MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  25%|▉   |  352kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  25%|▉   | 2.14MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  25%|▉   |  352kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  25%|▉   | 2.14MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  25%|▉   |  352kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  25%|▉   | 15.2MB / 61.4MB, 3.62MB/s
# New Data Upload                         :  25%|▉   | 15.2MB / 61.4MB, 3.62MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  28%|█   |  391kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  28%|█   | 2.38MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  28%|█   |  391kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  28%|█   | 2.38MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  28%|█   |  391kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  28%|█   | 2.38MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  28%|█   |  391kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  28%|█   | 2.38MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  28%|█   |  391kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  28%|█   | 16.9MB / 61.4MB, 3.84MB/s
# New Data Upload                         :  28%|█   | 16.9MB / 61.4MB, 3.84MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  30%|█▏  |  430kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  30%|█▏  | 2.62MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  30%|█▏  |  430kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  30%|█▏  | 2.62MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  30%|█▏  |  430kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  30%|█▏  | 2.62MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  30%|█▏  |  430kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  30%|█▏  | 2.62MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  30%|█▏  |  430kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  30%|█▏  | 18.6MB / 61.4MB, 4.04MB/s
# New Data Upload                         :  30%|█▏  | 18.6MB / 61.4MB, 4.04MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  36%|█▍  |  508kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  36%|█▍  | 3.10MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  36%|█▍  |  508kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  36%|█▍  | 3.10MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  36%|█▍  |  508kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  36%|█▍  | 3.10MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  36%|█▍  |  508kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  36%|█▍  | 3.10MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  36%|█▍  |  508kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  36%|█▍  | 22.0MB / 61.4MB, 4.57MB/s
# New Data Upload                         :  36%|█▍  | 22.0MB / 61.4MB, 4.57MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  41%|█▋  | 3.57MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  41%|█▋  | 3.57MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  41%|█▋  | 3.57MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  41%|█▋  | 3.57MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  41%|█▋  | 25.3MB / 61.4MB, 5.07MB/s
# New Data Upload                         :  41%|█▋  | 25.3MB / 61.4MB, 5.07MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  41%|█▋  | 3.57MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  41%|█▋  | 3.57MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  41%|█▋  | 3.57MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  41%|█▋  | 3.57MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  41%|█▋  |  586kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           :  41%|█▋  | 8.11MB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  47%|█▊  |  664kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  47%|█▊  | 4.05MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  47%|█▊  |  664kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  47%|█▊  | 4.05MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  47%|█▊  |  664kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  47%|█▊  | 4.05MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  47%|█▊  |  664kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  47%|█▊  | 4.05MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  47%|█▊  |  664kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  47%|█▊  | 28.7MB / 61.4MB, 5.32MB/s
# New Data Upload                         :  47%|█▊  | 28.7MB / 61.4MB, 5.32MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  52%|██  |  743kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  52%|██  | 4.53MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  52%|██  |  743kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  52%|██  | 4.53MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  52%|██  |  743kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  52%|██  | 4.53MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  52%|██  |  743kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  52%|██  | 4.53MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  52%|██  |  743kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  52%|██  | 32.1MB / 61.4MB, 5.73MB/s
# New Data Upload                         :  52%|██  | 32.1MB / 61.4MB, 5.73MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  58%|██▎ | 5.00MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  58%|██▎ | 5.00MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  58%|██▎ | 5.00MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  58%|██▎ | 5.00MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  58%|██▎ | 35.5MB / 61.4MB, 6.12MB/s
# New Data Upload                         :  58%|██▎ | 35.5MB / 61.4MB, 6.12MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  58%|██▎ | 5.00MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  58%|██▎ | 5.00MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  58%|██▎ | 5.00MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  58%|██▎ | 5.00MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  58%|██▎ |  821kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           :  58%|██▎ | 11.3MB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  64%|██▌ |  912kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  64%|██▌ | 5.56MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  64%|██▌ |  912kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  64%|██▌ | 5.56MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  64%|██▌ |  912kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  64%|██▌ | 5.56MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  64%|██▌ |  912kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  64%|██▌ | 5.56MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  64%|██▌ |  912kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  64%|██▌ | 39.4MB / 61.4MB, 6.36MB/s
# New Data Upload                         :  64%|██▌ | 39.4MB / 61.4MB, 6.36MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  69%|██▊ |  977kB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  69%|██▊ | 5.96MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  69%|██▊ |  977kB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  69%|██▊ | 5.96MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  69%|██▊ |  977kB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  69%|██▊ | 5.96MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  69%|██▊ |  977kB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  69%|██▊ | 5.96MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  69%|██▊ |  977kB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  69%|██▊ | 42.2MB / 61.4MB, 6.60MB/s
# New Data Upload                         :  69%|██▊ | 42.2MB / 61.4MB, 6.60MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  72%|██▊ | 1.02MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  72%|██▊ | 6.19MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  72%|██▊ | 1.02MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  72%|██▊ | 6.19MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  72%|██▊ | 1.02MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  72%|██▊ | 6.19MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  72%|██▊ | 1.02MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  72%|██▊ | 6.19MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  72%|██▊ | 1.02MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  72%|██▊ | 43.9MB / 61.4MB, 6.65MB/s
# New Data Upload                         :  72%|██▊ | 43.9MB / 61.4MB, 6.65MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  74%|██▉ | 1.06MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  74%|██▉ | 6.43MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  74%|██▉ | 1.06MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  74%|██▉ | 6.43MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  74%|██▉ | 1.06MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  74%|██▉ | 6.43MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  74%|██▉ | 1.06MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  74%|██▉ | 6.43MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  74%|██▉ | 1.06MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  74%|██▉ | 45.6MB / 61.4MB, 6.71MB/s
# New Data Upload                         :  74%|██▉ | 45.6MB / 61.4MB, 6.71MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  79%|███▏| 1.12MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  79%|███▏| 6.83MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  79%|███▏| 1.12MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  79%|███▏| 6.83MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  79%|███▏| 1.12MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  79%|███▏| 6.83MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  79%|███▏| 1.12MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  79%|███▏| 6.83MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  79%|███▏| 1.12MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  79%|███▏| 48.4MB / 61.4MB, 6.92MB/s
# New Data Upload                         :  79%|███▏| 48.4MB / 61.4MB, 6.92MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  82%|███▎| 1.16MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  82%|███▎| 7.07MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  82%|███▎| 1.16MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  82%|███▎| 7.07MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  82%|███▎| 1.16MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  82%|███▎| 7.07MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  82%|███▎| 1.16MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  82%|███▎| 7.07MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  82%|███▎| 1.16MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  82%|███▎| 50.1MB / 61.4MB, 6.96MB/s
# New Data Upload                         :  82%|███▎| 50.1MB / 61.4MB, 6.96MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  84%|███▍| 1.20MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  84%|███▍| 7.31MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  84%|███▍| 1.20MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  84%|███▍| 7.31MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  84%|███▍| 1.20MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  84%|███▍| 7.31MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  84%|███▍| 1.20MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  84%|███▍| 7.31MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  84%|███▍| 1.20MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  84%|███▍| 51.8MB / 61.4MB, 7.00MB/s
# New Data Upload                         :  84%|███▍| 51.8MB / 61.4MB, 7.00MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  87%|███▍| 1.24MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  87%|███▍| 7.54MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  87%|███▍| 1.24MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  87%|███▍| 7.54MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  87%|███▍| 1.24MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  87%|███▍| 7.54MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  87%|███▍| 1.24MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  87%|███▍| 7.54MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  87%|███▍| 1.24MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  87%|███▍| 53.5MB / 61.4MB, 7.04MB/s
# New Data Upload                         :  87%|███▍| 53.5MB / 61.4MB, 7.04MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  90%|███▌| 1.28MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  90%|███▌| 7.78MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  90%|███▌| 1.28MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  90%|███▌| 7.78MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  90%|███▌| 1.28MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  90%|███▌| 7.78MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  90%|███▌| 1.28MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  90%|███▌| 7.78MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  90%|███▌| 1.28MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  90%|███▌| 55.2MB / 61.4MB, 7.07MB/s
# New Data Upload                         :  90%|███▌| 55.2MB / 61.4MB, 7.07MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  93%|███▋| 1.32MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  93%|███▋| 8.02MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  93%|███▋| 1.32MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  93%|███▋| 8.02MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  93%|███▋| 1.32MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  93%|███▋| 8.02MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  93%|███▋| 1.32MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  93%|███▋| 8.02MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  93%|███▋| 1.32MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  93%|███▋| 56.9MB / 61.4MB, 7.11MB/s
# New Data Upload                         :  93%|███▋| 56.9MB / 61.4MB, 7.11MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  95%|███▊| 1.35MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  95%|███▊| 8.26MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  95%|███▊| 1.35MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  95%|███▊| 8.26MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  95%|███▊| 1.35MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  95%|███▊| 8.26MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  95%|███▊| 1.35MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  95%|███▊| 8.26MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  95%|███▊| 1.35MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  95%|███▊| 58.5MB / 61.4MB, 7.14MB/s
# New Data Upload                         :  95%|███▊| 58.5MB / 61.4MB, 7.14MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx:  98%|███▉| 1.39MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt:  98%|███▉| 8.50MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx:  98%|███▉| 1.39MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt:  98%|███▉| 8.50MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx:  98%|███▉| 1.39MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt:  98%|███▉| 8.50MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx:  98%|███▉| 1.39MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt:  98%|███▉| 8.50MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx:  98%|███▉| 1.39MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               :  98%|███▉| 60.2MB / 61.4MB, 7.17MB/s
# New Data Upload                         :  98%|███▉| 60.2MB / 61.4MB, 7.17MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 13)               : 100%|███▉| 61.4MB / 61.4MB, 7.13MB/s
# New Data Upload                         : 100%|███▉| 61.4MB / 61.4MB, 7.13MB/s
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           : 100%|███▉| 19.6MB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           : 100%|███▉| 19.6MB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|███▉| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|███▉| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
#   [+ 3 files]                           : 100%|███▉| 19.6MB / 19.6MB
#
#   ...ng_2/Pyramids/Pyramids-1499998.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#   ...ning_2/Pyramids/Pyramids-1499998.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#   ...ng_2/Pyramids/Pyramids-1999932.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (13 / 13)              : 100%|████| 61.4MB / 61.4MB, 6.53MB/s
# New Data Upload                         : 100%|████| 61.4MB / 61.4MB, 6.53MB/s
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|████| 8.66MB / 8.66MB
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-3000102.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#   ...s_Training_2/Pyramids/checkpoint.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ....1755000331.DESKTOP-92SAKPB.76376.0: 100%|████|  906kB /  906kB
#
#
#
#
#
#
#
#
#
#
#   ...s/Pyramids_Training_2/Pyramids.onnx: 100%|████| 1.42MB / 1.42MB
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|████| 8.66MB / 8.66MB
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-3000102.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#   ...s_Training_2/Pyramids/checkpoint.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ....1755000331.DESKTOP-92SAKPB.76376.0: 100%|████|  906kB /  906kB
#
#
#
#
#
#
#
#
#
#
#   ...s/Pyramids_Training_2/Pyramids.onnx: 100%|████| 1.42MB / 1.42MB
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|████| 8.66MB / 8.66MB
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-3000102.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#   ...s_Training_2/Pyramids/checkpoint.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ....1755000331.DESKTOP-92SAKPB.76376.0: 100%|████|  906kB /  906kB
#
#
#
#
#
#
#
#
#
#
#   ...s/Pyramids_Training_2/Pyramids.onnx: 100%|████| 1.42MB / 1.42MB
#
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|████| 8.66MB / 8.66MB
#
#
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|████| 1.42MB / 1.42MB
#
#
#
#
#
#
#
#   ...ning_2/Pyramids/Pyramids-3000102.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#   ...s_Training_2/Pyramids/checkpoint.pt: 100%|████| 8.66MB / 8.66MB
#
#
#
#
#
#
#
#
#
#   ....1755000331.DESKTOP-92SAKPB.76376.0: 100%|████|  906kB /  906kB
#
#
#
#
#
#
#
#
#
#
# Processing Files (13 / 13)              : 100%|████| 61.4MB / 61.4MB, 6.14MB/s
# New Data Upload                         : 100%|████| 61.4MB / 61.4MB, 6.14MB/s
#   ...ning_2/Pyramids/Pyramids-1999932.pt: 100%|████| 8.66MB / 8.66MB
#   ...ng_2/Pyramids/Pyramids-2499916.onnx: 100%|████| 1.42MB / 1.42MB
#   ...ning_2/Pyramids/Pyramids-2499916.pt: 100%|████| 8.66MB / 8.66MB
#   ...ng_2/Pyramids/Pyramids-2999974.onnx: 100%|████| 1.42MB / 1.42MB
#   ...ning_2/Pyramids/Pyramids-2999974.pt: 100%|████| 8.66MB / 8.66MB
#   ...ng_2/Pyramids/Pyramids-3000102.onnx: 100%|████| 1.42MB / 1.42MB
#   ...ning_2/Pyramids/Pyramids-3000102.pt: 100%|████| 8.66MB / 8.66MB
#   ...s_Training_2/Pyramids/checkpoint.pt: 100%|████| 8.66MB / 8.66MB
#   ....1755000331.DESKTOP-92SAKPB.76376.0: 100%|████|  906kB /  906kB
#   ...s/Pyramids_Training_2/Pyramids.onnx: 100%|████| 1.42MB / 1.42MB
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/LizardAPN/ppo-Pyramids

# %%
# !mlagents-push-to-hf --run-id="SnowballTarget1" --local-dir="./results/SnowballTarget1" --repo-id="LizardAPN/ppo-SnowballTarget" --commit-message="Fist model for Snowball Target"

# %% [markdown]
# ### Watch your agent playing 👀
#
# 👉 https://huggingface.co/spaces/unity/ML-Agents-Pyramids

# %% [markdown]
# ### 🎁 Bonus: Why not train on another environment?
# Now that you know how to train an agent using MLAgents, **why not try another environment?**
#
# MLAgents provides 17 different and we’re building some custom ones. The best way to learn is to try things of your own, have fun.

# %% [markdown]
# ![cover](https://miro.medium.com/max/1400/0*xERdThTRRM2k_U9f.png)

# %% [markdown]
# You have the full list of the Unity official environments here 👉 https://github.com/Unity-Technologies/ml-agents/blob/develop/docs/Learning-Environment-Examples.md
#
# For the demos to visualize your agent 👉 https://huggingface.co/unity
#
# For now we have integrated:
# - [Worm](https://huggingface.co/spaces/unity/ML-Agents-Worm) demo where you teach a **worm to crawl**.
# - [Walker](https://huggingface.co/spaces/unity/ML-Agents-Walker) demo where you teach an agent **to walk towards a goal**.

# %% [markdown]
# That’s all for today. Congrats on finishing this tutorial!
#
# The best way to learn is to practice and try stuff. Why not try another environment? ML-Agents has 17 different environments, but you can also create your own? Check the documentation and have fun!
#
# See you on Unit 6 🔥,
#
# ## Keep Learning, Stay  awesome 🤗
